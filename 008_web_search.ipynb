# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-sonnet-4-5"

# %%
# Helper functions
from anthropic.types import Message


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[], tools=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
web_search_schema = {
    "type": "web_search_20250305",
    "name": "web_search",
    "max_uses": 5,
}

# %%
messages = []
add_user_message(
    messages,
    """
    Use web search to find out when Claude Shannon was born?
    """,
)
response = chat(messages, tools=[web_search_schema])
response
# Out:
# Message(id='msg_01D5nrdVKk5eaeFt8SYuHKsa', container=None, content=[ServerToolUseBlock(id='srvtoolu_01HVSybfF9FDnqSSBi7L7vs8', caller=None, input={'query': 'Claude Shannon born'}, name='web_search', type='server_tool_use'), WebSearchToolResultBlock(caller=DirectCaller(type='direct'), content=[WebSearchResultBlock(encrypted_content='...', page_age='20 hours ago', title='Claude Shannon - Wikipedia', type='web_search_result', url='https://en.wikipedia.org/wiki/Claude_Shannon'), WebSearchResultBlock(encrypted_content='...', page_age='April 26, 2026', title='Claude Shannon | Father of Information Theory, American Engineer | Britannica', type='web_search_result', url='https://www.britannica.com/biography/Claude-Shannon'), WebSearchResultBlock(encrypted_content='...', page_age='October 24, 2025', title='Claude Shannon: Tinkerer, Prankster, and Father of Information Theory - IEEE Spectrum', type='web_search_result', url='https://spectrum.ieee.org/claude-shannon-tinkerer-prankster-and-father-of-information-theory'), WebSearchResultBlock(encrypted_content='...', page_age=None, title='Claude E. Shannon | IEEE Information Theory Society', type='web_search_result', url='https://www.itsoc.org/about/shannon'), WebSearchResultBlock(encrypted_content='...', page_age=None, title='Claude Shannon - Magnet Academy', type='web_search_result', url='https://nationalmaglab.org/magnet-academy/history-of-electricity-magnetism/pioneers/claude-shannon/'), WebSearchResultBlock(encrypted_content='...', page_age='February 26, 2021', title='How Claude Shannon Invented the Future | Quanta Magazine', type='web_search_result', url='https://www.quantamagazine.org/how-claude-shannons-information-theory-invented-the-future-20201222/'), WebSearchResultBlock(encrypted_content='...', page_age='3 weeks ago', title='National Inventors Hall of Fame Inductee Claude Shannon Invented PCM', type='web_search_result', url='https://www.invent.org/inductees/claude-shannon'), WebSearchResultBlock(encrypted_content='...', page_age=None, title='Claude Shannon summary | Britannica', type='web_search_result', url='https://www.britannica.com/summary/Claude-Shannon'), WebSearchResultBlock(encrypted_content='...', page_age=None, title='Claude Shannon | Biography | Research Starters | EBSCO Research', type='web_search_result', url='https://www.ebsco.com/research-starters/biography/claude-shannon'), WebSearchResultBlock(encrypted_content='...', page_age='February 29, 2016', title='Claude Shannon - Engineering and Technology History Wiki', type='web_search_result', url='https://ethw.org/Claude_Shannon')], tool_use_id='srvtoolu_01HVSybfF9FDnqSSBi7L7vs8', type='web_search_tool_result'), TextBlock(citations=[CitationsWebSearchResultLocation(cited_text='Claude Elwood Shannon (April 30, 1916 – February 24, 2001) was an American polymath who was a mathematician, electrical engineer, computer scientist, ...', encrypted_index='Eo8BCioIEBgCIiQzYzUzMTM0ZC0yNDFlLTQ0M2EtOTRkOS04OWU4NzIzOTM5NzESDIpz+mtHlK1w2BvvDRoMBl0GkgzlNtYH7EhfIjDo+jhP39axMVo+WYHusdMMGTdv4zwa2lunTf/ZbZ63Qv+qfETWkE7NKI7sJWX9+ccqE8FMLeglkNFufKHBRnDcZ7ndWkEYBA==', title='Claude Shannon - Wikipedia', type='web_search_result_location', url='https://en.wikipedia.org/wiki/Claude_Shannon'), CitationsWebSearchResultLocation(cited_text='Claude Shannon (born April 30, 1916, Petoskey, Michigan, U.S.—died February 24, 2001, Medford, Massachusetts) was an American mathematician and electr...', encrypted_index='Eo8BCioIEBgCIiQzYzUzMTM0ZC0yNDFlLTQ0M2EtOTRkOS04OWU4NzIzOTM5NzESDNXleuAFbbtrla4H6xoM8nWBIHJoGgUn+6/6IjBZblJlsps35x42E20pCQqUZ7pdHrEFkwuy1XArWqGb1z1fz88LpH8LUNEvplp8G24qE8kD2++wDPjEWxIuurb+VEc82CcYBA==', title='Claude Shannon | Father of Information Theory, American Engineer | Britannica', type='web_search_result_location', url='https://www.britannica.com/biography/Claude-Shannon'), CitationsWebSearchResultLocation(cited_text='Claude Elwood Shannon was born on April 30, 1916 in Petoskey, Michigan. ', encrypted_index='Eo8BCioIEBgCIiQzYzUzMTM0 ...
